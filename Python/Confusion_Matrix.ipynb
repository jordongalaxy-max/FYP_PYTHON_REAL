# %% [markdown]
# <h2 style="font-size: 24px;">3. Particle PID type confusion matrix creation</h2>

# %% [markdown]
# <h2 style="font-size: 24px;">3.1 NuMI RECO to TRUTH matrix (reco flashmatch cut)</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/NuMI_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totalrecoPhoton = combinedPID[combinedPID["reco_particle_pid"] == 0]
totalrecoPhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totalrecoPhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totalrecoPhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totalrecoPhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totalrecoPhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totalrecoPhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totalrecoPhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totalrecoElectron = combinedPID[combinedPID["reco_particle_pid"] == 1]
totalrecoElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totalrecoElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totalrecoElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totalrecoElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totalrecoElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totalrecoElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totalrecoElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totalrecoMuon = combinedPID[combinedPID["reco_particle_pid"] == 2]
totalrecoMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totalrecoMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totalrecoMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totalrecoMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totalrecoMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totalrecoMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totalrecoMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totalrecoPion = combinedPID[combinedPID["reco_particle_pid"] == 3]
totalrecoPion
percentagecorrectPion = (len(correctrecoPion)/len(totalrecoPion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totalrecoPion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totalrecoPion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totalrecoPion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totalrecoPion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totalrecoPion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totalrecoProton = combinedPID[combinedPID["reco_particle_pid"] == 4]
totalrecoProton
percentagecorrectProton = (len(correctrecoProton)/len(totalrecoProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totalrecoProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totalrecoProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totalrecoProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totalrecoProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totalrecoProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
particle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton',]

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])

# Add NULL to particle names
particle_names_with_null = particle_names + ['NULL']

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=particle_names_with_null, yticklabels=particle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('True Particle PID', fontsize=12)
plt.ylabel('Reconstructed Particle PID', fontsize=12)
plt.title('NuMI PID Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  74.59896837093301 %
# Percentage of reco photons that are actually NULL:  19.338793787552433 %
# Percentage of reco photons that are actually ELECTRON:  4.578562521256094 %
# Percentage of reco photons that are actually MUON:  0.569663303480331 %
# Percentage of reco photons that are actually PION:  0.23523410044212675 %
# Percentage of reco photons that are actually PROTON:  0.6731096247590976 %
# Percentage of correctly identified electrons:  55.964630225080384 %
# Percentage of reco electrons that are actually NULL:  13.62861736334405 %
# Percentage of reco electrons that are actually PHOTON:  22.778135048231512 %
# Percentage of reco electrons that are actually MUON:  5.17363344051447 %
# Percentage of reco electrons that are actually PION:  1.09967845659164 %
# Percentage of reco electrons that are actually PROTON:  1.35048231511254 %
# Percentage of correctly identified muons:  78.75152726868822 %
# Percentage of reco muons that are actually NULL:  1.284756932874227 %
# Percentage of reco muons that are actually PHOTON:  0.714576622607279 %
# Percentage of reco muons that are actually MUON:  1.3514013847236106 %
# Percentage of reco muons that are actually PION:  10.255840645710688 %
# Percentage of reco muons that are actually PROTON:  7.56784775445222 %
# Percentage of correctly identified pions:  51.44946461217028 %
# Percentage of reco pions that are actually NULL:  2.4059806738051708 %
# Percentage of reco pions that are actually PHOTON:  2.1415513188822146 %
# Percentage of reco pions that are actually ELECTRON:  2.748759467223818 %
# Percentage of reco pions that are actually MUON:  7.965526247061897 %
# Percentage of reco pions that are actually PROTON:  32.733742491512146 %
# Percentage of correctly identified protons:  91.97583708115799 %
# Percentage of reco protons that are actually NULL:  1.3443939375670688 %
# Percentage of reco protons that are actually PHOTON:  0.40150957956038924 %
# Percentage of reco protons that are actually ELECTRON:  0.35569166958052495 %
# Percentage of reco protons that are actually MUON:  1.5855408321979334 %
# Percentage of reco protons that are actually PION:  4.150138056597176 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.2 NuMI RECO to TRUTH matrix (reco flashmatch cut) energy cut</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/NuMI_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid","reco_particle_ke"],library="pd")
combinedPID

#applying energy cut of 10 MeV to remove low energy particles that are more likely to be misidentified
combinedPID = combinedPID[combinedPID["reco_particle_ke"] > 10]

correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totalrecoPhoton = combinedPID[combinedPID["reco_particle_pid"] == 0]
totalrecoPhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totalrecoPhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totalrecoPhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totalrecoPhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totalrecoPhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totalrecoPhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totalrecoPhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totalrecoElectron = combinedPID[combinedPID["reco_particle_pid"] == 1]
totalrecoElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totalrecoElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totalrecoElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totalrecoElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totalrecoElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totalrecoElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totalrecoElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totalrecoMuon = combinedPID[combinedPID["reco_particle_pid"] == 2]
totalrecoMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totalrecoMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totalrecoMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totalrecoMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totalrecoMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totalrecoMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totalrecoMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totalrecoPion = combinedPID[combinedPID["reco_particle_pid"] == 3]
totalrecoPion
percentagecorrectPion = (len(correctrecoPion)/len(totalrecoPion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totalrecoPion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totalrecoPion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totalrecoPion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totalrecoPion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totalrecoPion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totalrecoProton = combinedPID[combinedPID["reco_particle_pid"] == 4]
totalrecoProton
percentagecorrectProton = (len(correctrecoProton)/len(totalrecoProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totalrecoProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totalrecoProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totalrecoProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totalrecoProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totalrecoProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
particle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton',]

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])

# Add NULL to particle names
particle_names_with_null = particle_names + ['NULL']

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=particle_names_with_null, yticklabels=particle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('True Particle PID', fontsize=12)
plt.ylabel('Reconstructed Particle PID', fontsize=12)
plt.title('NuMI PID Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  86.26833679415901 %
# Percentage of reco photons that are actually NULL:  6.922767767432514 %
# Percentage of reco photons that are actually ELECTRON:  5.710362381941189 %
# Percentage of reco photons that are actually MUON:  0.4655368745394869 %
# Percentage of reco photons that are actually PION:  0.2712840779690535 %
# Percentage of reco photons that are actually PROTON:  0.3550137316632058 %
# Percentage of correctly identified electrons:  80.79814686877718 %
# Percentage of reco electrons that are actually NULL:  5.94139878896249 %
# Percentage of reco electrons that are actually PHOTON:  10.464501970983866 %
# Percentage of reco electrons that are actually MUON:  0.8290323891575567 %
# Percentage of reco electrons that are actually PION:  0.816840736375828 %
# Percentage of reco electrons that are actually PROTON:  1.1460153614825048 %
# Percentage of correctly identified muons:  79.82729491270885 %
# Percentage of reco muons that are actually NULL:  0.64952130655153 %
# Percentage of reco muons that are actually PHOTON:  0.6007133470996808 %
# Percentage of reco muons that are actually MUON:  1.0925474000375446 %
# Percentage of reco muons that are actually PION:  10.366059695888868 %
# Percentage of reco muons that are actually PROTON:  7.388774169326075 %
# Percentage of correctly identified pions:  52.21071499701255 %
# Percentage of reco pions that are actually NULL:  1.649737768040895 %
# Percentage of reco pions that are actually PHOTON:  1.9650799973444866 %
# Percentage of reco pions that are actually ELECTRON:  2.585806280289451 %
# Percentage of reco pions that are actually MUON:  8.089358029608976 %
# Percentage of reco pions that are actually PROTON:  32.93500630684459 %
# Percentage of correctly identified protons:  92.15918569649787 %
# Percentage of reco protons that are actually NULL:  1.2088828713385962 %
# Percentage of reco protons that are actually PHOTON:  0.3687092757582718 %
# Percentage of reco protons that are actually ELECTRON:  0.3336516724894525 %
# Percentage of reco protons that are actually MUON:  1.5872632100675763 %
# Percentage of reco protons that are actually PION:  4.154930428790755 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.2. NuMI RECO to TRUTH matrix (true neutrino cut)</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/NuMI_simulation/particle_fiducial_trueneutrino_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totalrecoPhoton = combinedPID[combinedPID["reco_particle_pid"] == 0]
totalrecoPhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totalrecoPhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totalrecoPhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totalrecoPhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totalrecoPhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totalrecoPhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totalrecoPhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totalrecoElectron = combinedPID[combinedPID["reco_particle_pid"] == 1]
totalrecoElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totalrecoElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totalrecoElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totalrecoElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totalrecoElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totalrecoElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totalrecoElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totalrecoMuon = combinedPID[combinedPID["reco_particle_pid"] == 2]
totalrecoMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totalrecoMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totalrecoMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totalrecoMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totalrecoMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totalrecoMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totalrecoMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totalrecoPion = combinedPID[combinedPID["reco_particle_pid"] == 3]
totalrecoPion
percentagecorrectPion = (len(correctrecoPion)/len(totalrecoPion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totalrecoPion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totalrecoPion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totalrecoPion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totalrecoPion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totalrecoPion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totalrecoProton = combinedPID[combinedPID["reco_particle_pid"] == 4]
totalrecoProton
percentagecorrectProton = (len(correctrecoProton)/len(totalrecoProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totalrecoProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totalrecoProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totalrecoProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totalrecoProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totalrecoProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
particle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])

# Add NULL to particle names
particle_names_with_null = particle_names + ['NULL']

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=particle_names_with_null, yticklabels=particle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('True Particle PID', fontsize=12)
plt.ylabel('Reconstructed Particle PID', fontsize=12)
plt.title('NuMI PID Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  75.7729255693039 %
# Percentage of reco photons that are actually NULL:  18.52008881252301 %
# Percentage of reco photons that are actually ELECTRON:  4.18512278666027 %
# Percentage of reco photons that are actually MUON:  0.4574514376248229 %
# Percentage of reco photons that are actually PION:  0.2242627779575351 %
# Percentage of reco photons that are actually PROTON:  0.8301069990069956 %
# Percentage of correctly identified electrons:  42.96799338608716 %
# Percentage of reco electrons that are actually NULL:  10.342506200543285 %
# Percentage of reco electrons that are actually PHOTON:  40.685012401086574 %
# Percentage of reco electrons that are actually MUON:  3.7498523680170073 %
# Percentage of reco electrons that are actually PION:  0.9436636352899492 %
# Percentage of reco electrons that are actually PROTON:  1.306247785520255 %
# Percentage of correctly identified muons:  74.33458152008906 %
# Percentage of reco muons that are actually NULL:  1.116621124717471 %
# Percentage of reco muons that are actually PHOTON:  2.1927605168167865 %
# Percentage of reco muons that are actually MUON:  2.196133994534966 %
# Percentage of reco muons that are actually PION:  11.027898660729345 %
# Percentage of reco muons that are actually PROTON:  9.061161151030598 %
# Percentage of correctly identified pions:  47.09369075908472 %
# Percentage of reco pions that are actually NULL:  3.6472378714655704 %
# Percentage of reco pions that are actually PHOTON:  3.703308146209917 %
# Percentage of reco pions that are actually ELECTRON:  2.699383226977812 %
# Percentage of reco pions that are actually MUON:  6.811203374896537 %
# Percentage of reco pions that are actually PROTON:  35.52452407016794 %
# Percentage of correctly identified protons:  93.06942550760954 %
# Percentage of reco protons that are actually NULL:  1.0179828278733831 %
# Percentage of reco protons that are actually PHOTON:  0.5306408224932749 %
# Percentage of reco protons that are actually ELECTRON:  0.362973062608247 %
# Percentage of reco protons that are actually MUON:  1.224343147731879 %
# Percentage of reco protons that are actually PION:  3.6278881232265907 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.3. NuMI TRUTH to RECO matrix (true neutrino cut)</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/NuMI_simulation/particle_fiducial_neutrino_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totaltruePhoton = combinedPID[combinedPID["true_particle_pid"] == 0]
totaltruePhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totaltruePhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totaltruePhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totaltruePhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totaltruePhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totaltruePhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totaltruePhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totaltrueElectron = combinedPID[combinedPID["true_particle_pid"] == 1]
totaltrueElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totaltrueElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totaltrueElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totaltrueElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totaltrueElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totaltrueElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totaltrueElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totaltrueMuon = combinedPID[combinedPID["true_particle_pid"] == 2]
totaltrueMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totaltrueMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totaltrueMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totaltrueMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totaltrueMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totaltrueMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totaltrueMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totaltruePion = combinedPID[combinedPID["true_particle_pid"] == 3]
totaltruePion
percentagecorrectPion = (len(correctrecoPion)/len(totaltruePion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totaltruePion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totaltruePion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totaltruePion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totaltruePion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totaltruePion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totaltrueProton = combinedPID[combinedPID["true_particle_pid"] == 4]
totaltrueProton
percentagecorrectProton = (len(correctrecoProton)/len(totaltrueProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totaltrueProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totaltrueProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totaltrueProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totaltrueProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totaltrueProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
yparticle_names = ['Photon', 'Electron', 'Muon', 'Pion','Proton']
xparticle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])



# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('Reconstructed Particle PID', fontsize=12)
plt.ylabel('True Particle PID', fontsize=12)
plt.title('NuMI PID Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  59.812682022769394 %
# Percentage of reco photons that are actually NULL:  15.374856588121084 %
# Percentage of reco photons that are actually ELECTRON:  23.81960991968935 %
# Percentage of reco photons that are actually MUON:  0.22504633306857294 %
# Percentage of reco photons that are actually PION:  0.3221251434118789 %
# Percentage of reco photons that are actually PROTON:  0.4456799929397228 %
# Percentage of correctly identified electrons:  84.98018596700251 %
# Percentage of reco electrons that are actually NULL:  0.6164365821440597 %
# Percentage of reco electrons that are actually PHOTON:  4.3927581651946435 %
# Percentage of reco electrons that are actually MUON:  7.2780957807765025 %
# Percentage of reco electrons that are actually PION:  2.064285529280738 %
# Percentage of reco electrons that are actually PROTON:  0.6682379756015436 %
# Percentage of correctly identified muons:  83.55630549194488 %
# Percentage of reco muons that are actually NULL:  0.0883853601703427 %
# Percentage of reco muons that are actually PHOTON:  0.1526656221124101 %
# Percentage of reco muons that are actually MUON:  0.8798360853320477 %
# Percentage of reco muons that are actually PION:  9.983528182877345 %
# Percentage of reco muons that are actually PROTON:  5.339279257562975 %
# Percentage of correctly identified pions:  67.163708442202 %
# Percentage of reco pions that are actually NULL:  0.2567798900801874 %
# Percentage of reco pions that are actually PHOTON:  0.8964771601045138 %
# Percentage of reco pions that are actually ELECTRON:  1.7163708442202001 %
# Percentage of reco pions that are actually MUON:  13.492206505090548 %
# Percentage of reco pions that are actually PROTON:  16.47445715830255 %
# Percentage of correctly identified protons:  79.5740426826618 %
# Percentage of reco protons that are actually NULL:  1.7594645108010607 %
# Percentage of reco protons that are actually PHOTON:  0.6050332507497718 %
# Percentage of reco protons that are actually ELECTRON:  0.8762550528100143 %
# Percentage of reco protons that are actually MUON:  4.028339201112704 %
# Percentage of reco protons that are actually PION:  13.15686530186465 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.4. NuMI TRUTH to RECO matrix (Reco flashmatch cut)</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/NuMI_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totaltruePhoton = combinedPID[combinedPID["true_particle_pid"] == 0]
totaltruePhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totaltruePhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totaltruePhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totaltruePhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totaltruePhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totaltruePhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totaltruePhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totaltrueElectron = combinedPID[combinedPID["true_particle_pid"] == 1]
totaltrueElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totaltrueElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totaltrueElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totaltrueElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totaltrueElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totaltrueElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totaltrueElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totaltrueMuon = combinedPID[combinedPID["true_particle_pid"] == 2]
totaltrueMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totaltrueMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totaltrueMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totaltrueMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totaltrueMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totaltrueMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totaltrueMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totaltruePion = combinedPID[combinedPID["true_particle_pid"] == 3]
totaltruePion
percentagecorrectPion = (len(correctrecoPion)/len(totaltruePion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totaltruePion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totaltruePion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totaltruePion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totaltruePion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totaltruePion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totaltrueProton = combinedPID[combinedPID["true_particle_pid"] == 4]
totaltrueProton
percentagecorrectProton = (len(correctrecoProton)/len(totaltrueProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totaltrueProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totaltrueProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totaltrueProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totaltrueProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totaltrueProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
yparticle_names = ['Photon', 'Electron', 'Muon', 'Pion','Proton']
xparticle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])



# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('Reconstructed Particle PID', fontsize=12)
plt.ylabel('True Particle PID', fontsize=12)
plt.title('NuMI PID Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  60.66235571402672 %
# Percentage of reco photons that are actually NULL:  15.004532543663505 %
# Percentage of reco photons that are actually ELECTRON:  23.338369492959448 %
# Percentage of reco photons that are actually MUON:  0.22602284402006406 %
# Percentage of reco photons that are actually PION:  0.31304768235934005 %
# Percentage of reco photons that are actually PROTON:  0.45567172297093134 %
# Percentage of correctly identified electrons:  85.05229674358421 %
# Percentage of reco electrons that are actually NULL:  0.5876644382143626 %
# Percentage of reco electrons that are actually PHOTON:  4.353569117964201 %
# Percentage of reco electrons that are actually MUON:  7.370066853569118 %
# Percentage of reco electrons that are actually PION:  1.9867371145136943 %
# Percentage of reco electrons that are actually PROTON:  0.6496657321544101 %
# Percentage of correctly identified muons:  83.80570221752905 %
# Percentage of reco muons that are actually NULL:  0.0675818373812038 %
# Percentage of reco muons that are actually PHOTON:  0.14783526927138332 %
# Percentage of reco muons that are actually MUON:  0.8447729672650475 %
# Percentage of reco muons that are actually PION:  9.883843717001056 %
# Percentage of reco muons that are actually PROTON:  5.25026399155227 %
# Percentage of correctly identified pions:  67.63821532492726 %
# Percentage of reco pions that are actually NULL:  0.24733268671193018 %
# Percentage of reco pions that are actually PHOTON:  0.8729388942774006 %
# Percentage of reco pions that are actually ELECTRON:  1.6682832201745879 %
# Percentage of reco pions that are actually MUON:  13.186226964112514 %
# Percentage of reco pions that are actually PROTON:  16.387002909796315 %
# Percentage of correctly identified protons:  79.63937667718093 %
# Percentage of reco protons that are actually NULL:  1.5441834188597525 %
# Percentage of reco protons that are actually PHOTON:  0.614848641777694 %
# Percentage of reco protons that are actually ELECTRON:  0.866249234970105 %
# Percentage of reco protons that are actually MUON:  4.094910785744551 %
# Percentage of reco protons that are actually PION:  13.240431241466974 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.2 NuMI TRUTH to RECO matrix (reco flashmatch cut) energy cut</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/NuMI_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid","true_particle_ke"],library="pd")
combinedPID

#applying energy cut of 10 MeV to remove low energy particles that are more likely to be misidentified
combinedPID = combinedPID[combinedPID["true_particle_ke"] > 10]

correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totaltruePhoton = combinedPID[combinedPID["true_particle_pid"] == 0]
totaltruePhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totaltruePhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totaltruePhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totaltruePhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totaltruePhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totaltruePhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totaltruePhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totaltrueElectron = combinedPID[combinedPID["true_particle_pid"] == 1]
totaltrueElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totaltrueElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totaltrueElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totaltrueElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totaltrueElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totaltrueElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totaltrueElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totaltrueMuon = combinedPID[combinedPID["true_particle_pid"] == 2]
totaltrueMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totaltrueMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totaltrueMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totaltrueMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totaltrueMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totaltrueMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totaltrueMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totaltruePion = combinedPID[combinedPID["true_particle_pid"] == 3]
totaltruePion
percentagecorrectPion = (len(correctrecoPion)/len(totaltruePion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totaltruePion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totaltruePion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totaltruePion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totaltruePion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totaltruePion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totaltrueProton = combinedPID[combinedPID["true_particle_pid"] == 4]
totaltrueProton
percentagecorrectProton = (len(correctrecoProton)/len(totaltrueProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totaltrueProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totaltrueProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totaltrueProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totaltrueProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totaltrueProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
yparticle_names = ['Photon', 'Electron', 'Muon', 'Pion','Proton']
xparticle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])



# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('Reconstructed Particle PID', fontsize=12)
plt.ylabel('True Particle PID', fontsize=12)
plt.title('NuMI PID Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  90.59041287349375 %
# Percentage of reco photons that are actually NULL:  0.24553318475427793 %
# Percentage of reco photons that are actually ELECTRON:  8.570996864730104 %
# Percentage of reco photons that are actually MUON:  0.13598761001775395 %
# Percentage of reco photons that are actually PION:  0.25308805197748646 %
# Percentage of reco photons that are actually PROTON:  0.2039814150266309 %
# Percentage of correctly identified electrons:  90.31387528024578 %
# Percentage of reco electrons that are actually NULL:  0.22004483932574942 %
# Percentage of reco electrons that are actually PHOTON:  6.372996761604252 %
# Percentage of reco electrons that are actually MUON:  1.266295773478369 %
# Percentage of reco electrons that are actually PION:  1.4240637714855102 %
# Percentage of reco electrons that are actually PROTON:  0.4027235738603338 %
# Percentage of correctly identified muons:  86.08855121823422 %
# Percentage of reco muons that are actually NULL:  0.04366430879399179 %
# Percentage of reco muons that are actually PHOTON:  0.08296218670858439 %
# Percentage of reco muons that are actually MUON:  0.34494803947253516 %
# Percentage of reco muons that are actually PION:  8.466509475155009 %
# Percentage of reco muons that are actually PROTON:  4.973364771635666 %
# Percentage of correctly identified pions:  67.78686927722579 %
# Percentage of reco pions that are actually NULL:  0.23865186051042273 %
# Percentage of reco pions that are actually PHOTON:  0.8766803039158386 %
# Percentage of reco pions that are actually ELECTRON:  1.651081239041496 %
# Percentage of reco pions that are actually MUON:  13.208649912331968 %
# Percentage of reco pions that are actually PROTON:  16.23806740697448 %
# Percentage of correctly identified protons:  80.75346227784534 %
# Percentage of reco protons that are actually NULL:  1.397661736435325 %
# Percentage of reco protons that are actually PHOTON:  0.5727961081250735 %
# Percentage of reco protons that are actually ELECTRON:  0.8170191062811409 %
# Percentage of reco protons that are actually MUON:  3.853623131546942 %
# Percentage of reco protons that are actually PION:  12.605437639766173 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.5. BNB RECO to TRUTH matrix (reco flashmatch cut)</h2>

# %%
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/BNB_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totalrecoPhoton = combinedPID[combinedPID["reco_particle_pid"] == 0]
totalrecoPhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totalrecoPhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totalrecoPhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totalrecoPhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totalrecoPhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totalrecoPhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totalrecoPhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totalrecoElectron = combinedPID[combinedPID["reco_particle_pid"] == 1]
totalrecoElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totalrecoElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totalrecoElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totalrecoElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totalrecoElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totalrecoElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totalrecoElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totalrecoMuon = combinedPID[combinedPID["reco_particle_pid"] == 2]
totalrecoMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totalrecoMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totalrecoMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totalrecoMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totalrecoMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totalrecoMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totalrecoMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totalrecoPion = combinedPID[combinedPID["reco_particle_pid"] == 3]
totalrecoPion
percentagecorrectPion = (len(correctrecoPion)/len(totalrecoPion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totalrecoPion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totalrecoPion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totalrecoPion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totalrecoPion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totalrecoPion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totalrecoProton = combinedPID[combinedPID["reco_particle_pid"] == 4]
totalrecoProton
percentagecorrectProton = (len(correctrecoProton)/len(totalrecoProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totalrecoProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totalrecoProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totalrecoProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totalrecoProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totalrecoProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
particle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])

# Add NULL to particle names
particle_names_with_null = particle_names + ['NULL']

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=particle_names_with_null, yticklabels=particle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('True Particle PID', fontsize=12)
plt.ylabel('Reconstructed Particle PID', fontsize=12)
plt.title('BNB PID Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  75.97371218710738 %
# Percentage of reco photons that are actually NULL:  18.388180148835414 %
# Percentage of reco photons that are actually ELECTRON:  4.272977674688316 %
# Percentage of reco photons that are actually MUON:  0.6439064463129409 %
# Percentage of reco photons that are actually PION:  0.14859379530298636 %
# Percentage of reco photons that are actually PROTON:  0.5726297477529719 %
# Percentage of correctly identified electrons:  66.77951265977576 %
# Percentage of reco electrons that are actually NULL:  8.027083038346184 %
# Percentage of reco electrons that are actually PHOTON:  15.777414496633929 %
# Percentage of reco electrons that are actually MUON:  7.364166462857363 %
# Percentage of reco electrons that are actually PION:  0.6835120419117742 %
# Percentage of reco electrons that are actually PROTON:  1.3631624338692445 %
# Percentage of correctly identified muons:  84.39048946716234 %
# Percentage of reco muons that are actually NULL:  0.6563661710037175 %
# Percentage of reco muons that are actually PHOTON:  0.43757744733581166 %
# Percentage of reco muons that are actually MUON:  0.8828996282527881 %
# Percentage of reco muons that are actually PION:  6.4920229244114 %
# Percentage of reco muons that are actually PROTON:  7.125154894671623 %
# Percentage of correctly identified pions:  47.84964833390983 %
# Percentage of reco pions that are actually NULL:  1.957223567393059 %
# Percentage of reco pions that are actually PHOTON:  1.7179753257235097 %
# Percentage of reco pions that are actually ELECTRON:  2.669203274530151 %
# Percentage of reco pions that are actually MUON:  13.32583881010031 %
# Percentage of reco pions that are actually PROTON:  32.321572696875364 %
# Percentage of correctly identified protons:  93.47535623293525 %
# Percentage of reco protons that are actually NULL:  0.9543806069860661 %
# Percentage of reco protons that are actually PHOTON:  0.23071113803663162 %
# Percentage of reco protons that are actually ELECTRON:  0.13693286969800078 %
# Percentage of reco protons that are actually MUON:  2.171838303028291 %
# Percentage of reco protons that are actually PION:  2.9743479090765748 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.5. BNB RECO to TRUTH matrix (reco flashmatch cut) energy cut</h2>

# %%
#BNB
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/BNB_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid","reco_particle_ke"],library="pd")
combinedPID

#applying energy cut of 10 MeV to remove low energy particles that are more likely to be misidentified
combinedPID = combinedPID[combinedPID["reco_particle_ke"] > 10]

correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totalrecoPhoton = combinedPID[combinedPID["reco_particle_pid"] == 0]
totalrecoPhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totalrecoPhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totalrecoPhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totalrecoPhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totalrecoPhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totalrecoPhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totalrecoPhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totalrecoElectron = combinedPID[combinedPID["reco_particle_pid"] == 1]
totalrecoElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totalrecoElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totalrecoElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totalrecoElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totalrecoElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totalrecoElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totalrecoElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totalrecoMuon = combinedPID[combinedPID["reco_particle_pid"] == 2]
totalrecoMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totalrecoMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totalrecoMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totalrecoMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totalrecoMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totalrecoMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totalrecoMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totalrecoPion = combinedPID[combinedPID["reco_particle_pid"] == 3]
totalrecoPion
percentagecorrectPion = (len(correctrecoPion)/len(totalrecoPion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totalrecoPion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totalrecoPion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totalrecoPion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totalrecoPion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totalrecoPion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totalrecoProton = combinedPID[combinedPID["reco_particle_pid"] == 4]
totalrecoProton
percentagecorrectProton = (len(correctrecoProton)/len(totalrecoProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totalrecoProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totalrecoProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totalrecoProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totalrecoProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totalrecoProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
particle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton',]

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])

# Add NULL to particle names
particle_names_with_null = particle_names + ['NULL']

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=particle_names_with_null, yticklabels=particle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('True Particle PID', fontsize=12)
plt.ylabel('Reconstructed Particle PID', fontsize=12)
plt.title('BNB PID Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  89.31271690629649 %
# Percentage of reco photons that are actually NULL:  4.7626425384234015 %
# Percentage of reco photons that are actually ELECTRON:  4.837010411502231 %
# Percentage of reco photons that are actually MUON:  0.55466038671294 %
# Percentage of reco photons that are actually PION:  0.19211700545364402 %
# Percentage of reco photons that are actually PROTON:  0.3408527516113039 %
# Percentage of correctly identified electrons:  88.87134699361773 %
# Percentage of reco electrons that are actually NULL:  1.561975142761169 %
# Percentage of reco electrons that are actually PHOTON:  6.963385959019147 %
# Percentage of reco electrons that are actually MUON:  0.8498488411152166 %
# Percentage of reco electrons that are actually PION:  0.6147127981189117 %
# Percentage of reco electrons that are actually PROTON:  1.1320120927107828 %
# Percentage of correctly identified muons:  85.080078125 %
# Percentage of reco muons that are actually NULL:  0.3515625 %
# Percentage of reco muons that are actually PHOTON:  0.361328125 %
# Percentage of reco muons that are actually MUON:  0.69921875 %
# Percentage of reco muons that are actually PION:  6.525390624999999 %
# Percentage of reco muons that are actually PROTON:  6.96875 %
# Percentage of correctly identified pions:  48.46385454120261 %
# Percentage of reco pions that are actually NULL:  1.3242129264228713 %
# Percentage of reco pions that are actually PHOTON:  1.5639159285568125 %
# Percentage of reco pions that are actually ELECTRON:  2.4818030342892223 %
# Percentage of reco pions that are actually MUON:  13.499371510421234 %
# Percentage of reco pions that are actually PROTON:  32.506065655236924 %
# Percentage of correctly identified protons:  93.61928600533874 %
# Percentage of reco protons that are actually NULL:  0.833243245490757 %
# Percentage of reco protons that are actually PHOTON:  0.21122134167130968 %
# Percentage of reco protons that are actually ELECTRON:  0.12723175305397785 %
# Percentage of reco protons that are actually MUON:  2.1754135031974253 %
# Percentage of reco protons that are actually PION:  2.977056705446018 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.6. BNB RECO to TRUTH matrix (true neutrino cut)</h2>

# %%
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/BNB_simulation/particle_fiducial_trueneutrino_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totalrecoPhoton = combinedPID[combinedPID["reco_particle_pid"] == 0]
totalrecoPhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totalrecoPhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totalrecoPhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totalrecoPhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totalrecoPhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totalrecoPhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totalrecoPhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totalrecoElectron = combinedPID[combinedPID["reco_particle_pid"] == 1]
totalrecoElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totalrecoElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totalrecoElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totalrecoElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totalrecoElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totalrecoElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totalrecoElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totalrecoMuon = combinedPID[combinedPID["reco_particle_pid"] == 2]
totalrecoMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totalrecoMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totalrecoMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totalrecoMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totalrecoMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totalrecoMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totalrecoMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totalrecoPion = combinedPID[combinedPID["reco_particle_pid"] == 3]
totalrecoPion
percentagecorrectPion = (len(correctrecoPion)/len(totalrecoPion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totalrecoPion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totalrecoPion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totalrecoPion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totalrecoPion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totalrecoPion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totalrecoProton = combinedPID[combinedPID["reco_particle_pid"] == 4]
totalrecoProton
percentagecorrectProton = (len(correctrecoProton)/len(totalrecoProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totalrecoProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totalrecoProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totalrecoProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totalrecoProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totalrecoProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
particle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])

# Add NULL to particle names
particle_names_with_null = particle_names + ['NULL']

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=particle_names_with_null, yticklabels=particle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('True Particle PID', fontsize=12)
plt.ylabel('Reconstructed Particle PID', fontsize=12)
plt.title('BNB PID Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  76.15189560269651 %
# Percentage of reco photons that are actually NULL:  18.32519017873709 %
# Percentage of reco photons that are actually ELECTRON:  4.098377553755128 %
# Percentage of reco photons that are actually MUON:  0.5957902983074608 %
# Percentage of reco photons that are actually PION:  0.1422475106685633 %
# Percentage of reco photons that are actually PROTON:  0.6844372977096089 %
# Percentage of correctly identified electrons:  57.16632051879795 %
# Percentage of reco electrons that are actually NULL:  7.413215784342814 %
# Percentage of reco electrons that are actually PHOTON:  27.223117026236594 %
# Percentage of reco electrons that are actually MUON:  6.2200652735981015 %
# Percentage of reco electrons that are actually PION:  0.6506167083456957 %
# Percentage of reco electrons that are actually PROTON:  1.3213665070147924 %
# Percentage of correctly identified muons:  81.86807235440662 %
# Percentage of reco muons that are actually NULL:  0.6119796367837672 %
# Percentage of reco muons that are actually PHOTON:  1.1752175325847565 %
# Percentage of reco muons that are actually MUON:  1.552514712784778 %
# Percentage of reco muons that are actually PION:  6.941184965880781 %
# Percentage of reco muons that are actually PROTON:  7.8365888002310715 %
# Percentage of correctly identified pions:  45.437021255009384 %
# Percentage of reco pions that are actually NULL:  2.8458377720286103 %
# Percentage of reco pions that are actually PHOTON:  2.74438187997768 %
# Percentage of reco pions that are actually ELECTRON:  2.6277076041191094 %
# Percentage of reco pions that are actually MUON:  12.27362654086136 %
# Percentage of reco pions that are actually PROTON:  33.91924110992746 %
# Percentage of correctly identified protons:  93.97362397511215 %
# Percentage of reco protons that are actually NULL:  0.783769036162508 %
# Percentage of reco protons that are actually PHOTON:  0.3181847172124468 %
# Percentage of reco protons that are actually ELECTRON:  0.14456499401189118 %
# Percentage of reco protons that are actually MUON:  1.9537533749548235 %
# Percentage of reco protons that are actually PION:  2.7722463557574426 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.7. BNB TRUTH to RECO matrix (true neutrino cut)</h2>

# %%
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/BNB_simulation/particle_fiducial_neutrino_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totaltruePhoton = combinedPID[combinedPID["true_particle_pid"] == 0]
totaltruePhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totaltruePhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totaltruePhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totaltruePhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totaltruePhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totaltruePhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totaltruePhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totaltrueElectron = combinedPID[combinedPID["true_particle_pid"] == 1]
totaltrueElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totaltrueElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totaltrueElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totaltrueElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totaltrueElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totaltrueElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totaltrueElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totaltrueMuon = combinedPID[combinedPID["true_particle_pid"] == 2]
totaltrueMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totaltrueMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totaltrueMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totaltrueMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totaltrueMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totaltrueMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totaltrueMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totaltruePion = combinedPID[combinedPID["true_particle_pid"] == 3]
totaltruePion
percentagecorrectPion = (len(correctrecoPion)/len(totaltruePion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totaltruePion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totaltruePion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totaltruePion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totaltruePion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totaltruePion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totaltrueProton = combinedPID[combinedPID["true_particle_pid"] == 4]
totaltrueProton
percentagecorrectProton = (len(correctrecoProton)/len(totaltrueProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totaltrueProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totaltrueProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totaltrueProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totaltrueProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totaltrueProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")


# Data from your analysis
yparticle_names = ['Photon', 'Electron', 'Muon', 'Pion','Proton']
xparticle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])



# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('Reconstructed Particle PID', fontsize=12)
plt.ylabel('True Particle PID', fontsize=12)
plt.title('BNB PID Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  59.68802647670033 %
# Percentage of reco photons that are actually NULL:  15.87062676917551 %
# Percentage of reco photons that are actually ELECTRON:  23.405710962688033 %
# Percentage of reco photons that are actually MUON:  0.28221289114279113 %
# Percentage of reco photons that are actually PION:  0.3010270838856439 %
# Percentage of reco photons that are actually PROTON:  0.45239581640768645 %
# Percentage of correctly identified electrons:  85.94747811588161 %
# Percentage of reco electrons that are actually NULL:  0.5819091288036682 %
# Percentage of reco electrons that are actually PHOTON:  2.937890787828262 %
# Percentage of reco electrons that are actually MUON:  8.827011254689454 %
# Percentage of reco electrons that are actually PION:  1.255523134639433 %
# Percentage of reco electrons that are actually PROTON:  0.45018757815756566 %
# Percentage of correctly identified muons:  85.08815031741976 %
# Percentage of reco muons that are actually NULL:  0.07468700249611823 %
# Percentage of reco muons that are actually PHOTON:  0.07861789736433498 %
# Percentage of reco muons that are actually MUON:  0.5955305725348375 %
# Percentage of reco muons that are actually PION:  9.044989091766741 %
# Percentage of reco muons that are actually PROTON:  5.118025118418208 %
# Percentage of correctly identified pions:  65.7458336753961 %
# Percentage of reco pions that are actually NULL:  0.18060914539036202 %
# Percentage of reco pions that are actually PHOTON:  0.5746654626056974 %
# Percentage of reco pions that are actually ELECTRON:  1.5721205155570148 %
# Percentage of reco pions that are actually MUON:  15.799195468352353 %
# Percentage of reco pions that are actually PROTON:  16.127575732698464 %
# Percentage of correctly identified protons:  80.83263850953107 %
# Percentage of reco protons that are actually NULL:  1.844685316695897 %
# Percentage of reco protons that are actually PHOTON:  0.4646214887438544 %
# Percentage of reco protons that are actually ELECTRON:  0.64805497254248 %
# Percentage of reco protons that are actually MUON:  5.473103131019809 %
# Percentage of reco protons that are actually PION:  10.736896581466892 %

# %% [markdown]
# <h2 style="font-size: 24px;">3.8. BNB TRUTH to RECO matrix (Reco flashmatch cut)</h2>

# %%
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix.root:events/BNB_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid"],library="pd")
combinedPID
correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totaltruePhoton = combinedPID[combinedPID["true_particle_pid"] == 0]
totaltruePhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totaltruePhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totaltruePhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totaltruePhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totaltruePhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totaltruePhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totaltruePhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totaltrueElectron = combinedPID[combinedPID["true_particle_pid"] == 1]
totaltrueElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totaltrueElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totaltrueElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totaltrueElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totaltrueElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totaltrueElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totaltrueElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totaltrueMuon = combinedPID[combinedPID["true_particle_pid"] == 2]
totaltrueMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totaltrueMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totaltrueMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totaltrueMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totaltrueMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totaltrueMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totaltrueMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totaltruePion = combinedPID[combinedPID["true_particle_pid"] == 3]
totaltruePion
percentagecorrectPion = (len(correctrecoPion)/len(totaltruePion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totaltruePion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totaltruePion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totaltruePion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totaltruePion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totaltruePion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totaltrueProton = combinedPID[combinedPID["true_particle_pid"] == 4]
totaltrueProton
percentagecorrectProton = (len(correctrecoProton)/len(totaltrueProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totaltrueProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totaltrueProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totaltrueProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totaltrueProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totaltrueProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")


# Data from your analysis
yparticle_names = ['Photon', 'Electron', 'Muon', 'Pion','Proton']
xparticle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])



# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('Reconstructed Particle PID', fontsize=12)
plt.ylabel('True Particle PID', fontsize=12)
plt.title('BNB PID Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  60.80384651293064 %
# Percentage of reco photons that are actually NULL:  15.494351601157689 %
# Percentage of reco photons that are actually ELECTRON:  22.67295303893194 %
# Percentage of reco photons that are actually MUON:  0.2791522733638316 %
# Percentage of reco photons that are actually PION:  0.29782466623097753 %
# Percentage of reco photons that are actually PROTON:  0.4518719073849314 %
# Percentage of correctly identified electrons:  85.96560755393205 %
# Percentage of reco electrons that are actually NULL:  0.5617203115307741 %
# Percentage of reco electrons that are actually PHOTON:  2.8758012268247297 %
# Percentage of reco electrons that are actually MUON:  8.927217589082638 %
# Percentage of reco electrons that are actually PION:  1.2354400716796472 %
# Percentage of reco electrons that are actually PROTON:  0.4342132469501689 %
# Percentage of correctly identified muons:  85.26700864482639 %
# Percentage of reco muons that are actually NULL:  0.07152929635609327 %
# Percentage of reco muons that are actually PHOTON:  0.07766037890090127 %
# Percentage of reco muons that are actually MUON:  0.5763217592119515 %
# Percentage of reco muons that are actually PION:  8.937074656148454 %
# Percentage of reco muons that are actually PROTON:  5.070405264556212 %
# Percentage of correctly identified pions:  66.3545238723292 %
# Percentage of reco pions that are actually NULL:  0.14508045370614614 %
# Percentage of reco pions that are actually PHOTON:  0.5319616635892025 %
# Percentage of reco pions that are actually ELECTRON:  1.4683900466016002 %
# Percentage of reco pions that are actually MUON:  15.35214982854128 %
# Percentage of reco pions that are actually PROTON:  16.14789413523257 %
# Percentage of correctly identified protons:  80.8516125862789 %
# Percentage of reco protons that are actually NULL:  1.6979440446071086 %
# Percentage of reco protons that are actually PHOTON:  0.45135221438923134 %
# Percentage of reco protons that are actually ELECTRON:  0.6306649308540689 %
# Percentage of reco protons that are actually MUON:  5.55439561789197 %
# Percentage of reco protons that are actually PION:  10.814030605978727 %

# %%
#BNB 
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/BNB_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting reco and true Photon PID from TBranches

combinedPID = file.arrays(["reco_particle_pid", "true_particle_pid","true_particle_ke"],library="pd")
combinedPID

#applying energy cut of 10 MeV to remove low energy particles that are more likely to be misidentified
combinedPID = combinedPID[combinedPID["true_particle_ke"] > 10]

correctrecoPhoton = combinedPID[(combinedPID["reco_particle_pid"] == 0) & (combinedPID["true_particle_pid"] == 0)]
correctrecoPhoton
totaltruePhoton = combinedPID[combinedPID["true_particle_pid"] == 0]
totaltruePhoton
percentagecorrectPhoton = (len(correctrecoPhoton)/len(totaltruePhoton))*100
percentagecorrectPhoton
wrongrecoPhotonNULL = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPhotonNULL = (len(wrongrecoPhotonNULL)/len(totaltruePhoton))*100
wrongrecoPhotoELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 1)] 
percentagewrongrecoPhotoELECTRON = (len(wrongrecoPhotoELECTRON)/len(totaltruePhoton))*100
wrongrecoPhotoMUON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPhotoMUON = (len(wrongrecoPhotoMUON)/len(totaltruePhoton))*100
wrongrecoPhotoPION = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoPhotoPION = (len(wrongrecoPhotoPION)/len(totaltruePhoton))*100
wrongrecoPhotoPROTON = combinedPID[(combinedPID["true_particle_pid"] == 0) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPhotoPROTON = (len(wrongrecoPhotoPROTON)/len(totaltruePhoton))*100

print("Percentage of correctly identified photons: ", percentagecorrectPhoton, "%")
print("Percentage of reco photons that are actually NULL: ", percenragewrongrecoPhotonNULL, "%")
print("Percentage of reco photons that are actually ELECTRON: ", percentagewrongrecoPhotoELECTRON, "%")
print("Percentage of reco photons that are actually MUON: ", percentagewrongrecoPhotoMUON, "%")
print("Percentage of reco photons that are actually PION: ", percentagewrongrecoPhotoPION, "%")
print("Percentage of reco photons that are actually PROTON: ", percentagewrongrecoPhotoPROTON, "%")

#Extracting reco and true Electron PID from TBranches

correctrecoElectron = combinedPID[(combinedPID["reco_particle_pid"] == 1) & (combinedPID["true_particle_pid"] == 1)]
correctrecoElectron
totaltrueElectron = combinedPID[combinedPID["true_particle_pid"] == 1]
totaltrueElectron
percentagecorrectElectron = (len(correctrecoElectron)/len(totaltrueElectron))*100
percentagecorrectElectron
wrongrecoElectronNULL = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoElectronNULL = (len(wrongrecoElectronNULL)/len(totaltrueElectron))*100
wrongrecoElectronPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoElectronPHOTON = (len(wrongrecoElectronPHOTON)/len(totaltrueElectron))*100
wrongrecoElectronMUON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoElectronMUON = (len(wrongrecoElectronMUON)/len(totaltrueElectron))*100
wrongrecoElectronPION = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoElectronPION = (len(wrongrecoElectronPION)/len(totaltrueElectron))*100
wrongrecoElectronPROTON = combinedPID[(combinedPID["true_particle_pid"] == 1) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoElectronPROTON = (len(wrongrecoElectronPROTON)/len(totaltrueElectron))*100

print("Percentage of correctly identified electrons: ", percentagecorrectElectron, "%")
print("Percentage of reco electrons that are actually NULL: ", percenragewrongrecoElectronNULL, "%")
print("Percentage of reco electrons that are actually PHOTON: ", percentagewrongrecoElectronPHOTON, "%")
print("Percentage of reco electrons that are actually MUON: ", percentagewrongrecoElectronMUON, "%")
print("Percentage of reco electrons that are actually PION: ", percentagewrongrecoElectronPION, "%")
print("Percentage of reco electrons that are actually PROTON: ", percentagewrongrecoElectronPROTON, "%")

#Extracting reco and true Muon PID from TBranches

correctrecoMuon = combinedPID[(combinedPID["reco_particle_pid"] == 2) & (combinedPID["true_particle_pid"] == 2)]
correctrecoMuon
totaltrueMuon = combinedPID[combinedPID["true_particle_pid"] == 2]
totaltrueMuon
percentagecorrectMuon = (len(correctrecoMuon)/len(totaltrueMuon))*100
percentagecorrectMuon
wrongrecoMuonNULL = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoMuonNULL = (len(wrongrecoMuonNULL)/len(totaltrueMuon))*100
wrongrecoMuonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoMuonPHOTON = (len(wrongrecoMuonPHOTON)/len(totaltrueMuon))*100
wrongrecoMuonMUON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoMuonMUON = (len(wrongrecoMuonMUON)/len(totaltrueMuon))*100
wrongrecoMuonPION = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoMuonPION = (len(wrongrecoMuonPION)/len(totaltrueMuon))*100
wrongrecoMuonPROTON = combinedPID[(combinedPID["true_particle_pid"] == 2) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoMuonPROTON = (len(wrongrecoMuonPROTON)/len(totaltrueMuon))*100

print("Percentage of correctly identified muons: ", percentagecorrectMuon, "%")
print("Percentage of reco muons that are actually NULL: ", percenragewrongrecoMuonNULL, "%")
print("Percentage of reco muons that are actually PHOTON: ", percentagewrongrecoMuonPHOTON, "%")
print("Percentage of reco muons that are actually MUON: ", percentagewrongrecoMuonMUON, "%")
print("Percentage of reco muons that are actually PION: ", percentagewrongrecoMuonPION, "%")
print("Percentage of reco muons that are actually PROTON: ", percentagewrongrecoMuonPROTON, "%")

#Extracting reco and true Pion PID from TBranches

correctrecoPion = combinedPID[(combinedPID["reco_particle_pid"] == 3) & (combinedPID["true_particle_pid"] == 3)]
correctrecoPion
totaltruePion = combinedPID[combinedPID["true_particle_pid"] == 3]
totaltruePion
percentagecorrectPion = (len(correctrecoPion)/len(totaltruePion))*100
percentagecorrectPion   
wrongrecoPionNULL = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoPionNULL = (len(wrongrecoPionNULL)/len(totaltruePion))*100
wrongrecoPionPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoPionPHOTON = (len(wrongrecoPionPHOTON)/len(totaltruePion))*100
wrongrecoPionELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoPionELECTRON = (len(wrongrecoPionELECTRON)/len(totaltruePion))*100
wrongrecoPionMUON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoPionMUON = (len(wrongrecoPionMUON)/len(totaltruePion))*100
wrongrecoPionPROTON = combinedPID[(combinedPID["true_particle_pid"] == 3) & (combinedPID["reco_particle_pid"] == 4)]
percentagewrongrecoPionPROTON = (len(wrongrecoPionPROTON)/len(totaltruePion))*100

print("Percentage of correctly identified pions: ", percentagecorrectPion, "%")
print("Percentage of reco pions that are actually NULL: ", percenragewrongrecoPionNULL, "%")
print("Percentage of reco pions that are actually PHOTON: ", percentagewrongrecoPionPHOTON, "%")
print("Percentage of reco pions that are actually ELECTRON: ", percentagewrongrecoPionELECTRON, "%")
print("Percentage of reco pions that are actually MUON: ", percentagewrongrecoPionMUON, "%")
print("Percentage of reco pions that are actually PROTON: ", percentagewrongrecoPionPROTON, "%")

#Extracting reco and true Proton PID from TBranches

correctrecoProton = combinedPID[(combinedPID["reco_particle_pid"] == 4) & (combinedPID["true_particle_pid"] == 4)]
correctrecoProton
totaltrueProton = combinedPID[combinedPID["true_particle_pid"] == 4]
totaltrueProton
percentagecorrectProton = (len(correctrecoProton)/len(totaltrueProton))*100
percentagecorrectProton   
wrongrecoProtonNULL = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"].isna())]
percenragewrongrecoProtonNULL = (len(wrongrecoProtonNULL)/len(totaltrueProton))*100
wrongrecoProtonPHOTON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 0)] 
percentagewrongrecoProtonPHOTON = (len(wrongrecoProtonPHOTON)/len(totaltrueProton))*100
wrongrecoProtonELECTRON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 1)]
percentagewrongrecoProtonELECTRON = (len(wrongrecoProtonELECTRON)/len(totaltrueProton))*100
wrongrecoProtonMUON = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 2)]
percentagewrongrecoProtonMUON = (len(wrongrecoProtonMUON)/len(totaltrueProton))*100
wrongrecoProtonPION = combinedPID[(combinedPID["true_particle_pid"] == 4) & (combinedPID["reco_particle_pid"] == 3)]
percentagewrongrecoProtonPION = (len(wrongrecoProtonPION)/len(totaltrueProton))*100

print("Percentage of correctly identified protons: ", percentagecorrectProton, "%")
print("Percentage of reco protons that are actually NULL: ", percenragewrongrecoProtonNULL, "%")
print("Percentage of reco protons that are actually PHOTON: ", percentagewrongrecoProtonPHOTON, "%")
print("Percentage of reco protons that are actually ELECTRON: ", percentagewrongrecoProtonELECTRON, "%")
print("Percentage of reco protons that are actually MUON: ", percentagewrongrecoProtonMUON, "%")
print("Percentage of reco protons that are actually PION: ", percentagewrongrecoProtonPION, "%")

# Data from your analysis
yparticle_names = ['Photon', 'Electron', 'Muon', 'Pion','Proton']
xparticle_names = ['Photon', 'Electron', 'Muon', 'Pion', 'Proton','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectPhoton, percentagewrongrecoPhotoELECTRON, percentagewrongrecoPhotoMUON, percentagewrongrecoPhotoPION, percentagewrongrecoPhotoPROTON, percenragewrongrecoPhotonNULL],
    [percentagewrongrecoElectronPHOTON, percentagecorrectElectron, percentagewrongrecoElectronMUON, percentagewrongrecoElectronPION, percentagewrongrecoElectronPROTON, percenragewrongrecoElectronNULL],
    [percentagewrongrecoMuonPHOTON, percentagewrongrecoMuonMUON, percentagecorrectMuon, percentagewrongrecoMuonPION, percentagewrongrecoMuonPROTON, percenragewrongrecoMuonNULL],
    [percentagewrongrecoPionPHOTON, percentagewrongrecoPionELECTRON, percentagewrongrecoPionMUON, percentagecorrectPion, percentagewrongrecoPionPROTON, percenragewrongrecoPionNULL],
    [percentagewrongrecoProtonPHOTON, percentagewrongrecoProtonELECTRON, percentagewrongrecoProtonMUON, percentagewrongrecoProtonPION, percentagecorrectProton, percenragewrongrecoProtonNULL]
])



# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})

# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")

plt.xlabel('Reconstructed Particle PID', fontsize=12)
plt.ylabel('True Particle PID', fontsize=12)
plt.title('BNB PID Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified photons:  92.45536445536445 %
# Percentage of reco photons that are actually NULL:  0.3013923013923014 %
# Percentage of reco photons that are actually ELECTRON:  6.5814905814905815 %
# Percentage of reco photons that are actually MUON:  0.19983619983619982 %
# Percentage of reco photons that are actually PION:  0.3013923013923014 %
# Percentage of reco photons that are actually PROTON:  0.16052416052416052 %
# Percentage of correctly identified electrons:  92.19582138467841 %
# Percentage of reco electrons that are actually NULL:  0.2516533036811611 %
# Percentage of reco electrons that are actually PHOTON:  4.643881313279101 %
# Percentage of reco electrons that are actually MUON:  1.556739041376485 %
# Percentage of reco electrons that are actually PION:  1.018318019547024 %
# Percentage of reco electrons that are actually PROTON:  0.3335869374378182 %
# Percentage of correctly identified muons:  86.89972786267532 %
# Percentage of reco muons that are actually NULL:  0.04605400879212895 %
# Percentage of reco muons that are actually PHOTON:  0.04605400879212895 %
# Percentage of reco muons that are actually MUON:  0.20933640360058614 %
# Percentage of reco muons that are actually PION:  7.885702323634081 %
# Percentage of reco muons that are actually PROTON:  4.913125392505757 %
# Percentage of correctly identified pions:  66.4989184655454 %
# Percentage of reco pions that are actually NULL:  0.1412616430494857 %
# Percentage of reco pions that are actually PHOTON:  0.525316735090275 %
# Percentage of reco pions that are actually ELECTRON:  1.4655895466384143 %
# Percentage of reco pions that are actually MUON:  15.379861387012758 %
# Percentage of reco pions that are actually PROTON:  15.989052222663666 %
# Percentage of correctly identified protons:  82.02533906630772 %
# Percentage of reco protons that are actually NULL:  1.4991642956479578 %
# Percentage of reco protons that are actually PHOTON:  0.4229557140487643 %
# Percentage of reco protons that are actually ELECTRON:  0.5996657182591832 %
# Percentage of reco protons that are actually MUON:  5.131607486890287 %
# Percentage of reco protons that are actually PION:  10.32126771884609 %
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <h2 style="font-size: 24px;">4. Particle semantic Type analysis</h2>

# %% [markdown]
# <h2 style="font-size: 24px;">4.1 NuMI Reco mode Particle semantic Type analysis</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/NuMI_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type"],library="pd")
combinedSEMANTIC

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)]
correctrecoSHOWER
totalrecoSHOWER = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 0]
totalrecoSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totalrecoSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totalrecoSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totalrecoSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totalrecoSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totalrecoSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totalrecoSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)]
correctrecoTRACK
totalrecoTRACK = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 1]
totalrecoTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totalrecoTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totalrecoTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totalrecoTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totalrecoTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totalrecoTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totalrecoTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)]
correctrecoMICHEL
totalrecoMICHEL = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 2]
totalrecoMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totalrecoMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totalrecoMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totalrecoMICHEL))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totalrecoMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totalrecoMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totalrecoMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)]
correctrecoDELTA
totalrecoDELTA = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 3]
totalrecoDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totalrecoDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totalrecoDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totalrecoDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totalrecoDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totalrecoDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totalrecoDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")


#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron', 'Low Energy','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta,percentagewrongrecoSHOWERlowe, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percentagewrongrecoTRACKlowe, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percentagewrongrecoMICHELlowe, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percentagewrongrecoDELTAlowe, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('True Particle Semantic Type', fontsize=12)
plt.ylabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.title('NuMI Semantic Type Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  42.28700505454656 %
# Percentage of reco showers that are actually NULL:  21.798365122615802 %
# Percentage of reco showers that are actually TRACK:  2.577920038896711 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  2.453329011476556 %
# Percentage of reco showers that are actually DELTA ELECTRON:  1.2752853944876068 %
# Percentage of reco showers that are actually LOW ENERGY:  29.608095377976763 %
#
# Percentage of correctly identified tracks:  96.5243494714678 %
# Percentage of reco tracks that are actually NULL:  1.5642561424974035 %
# Percentage of reco tracks that are actually SHOWER:  0.961032309465208 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.7006786268121612 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.09532074720084223 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.1543627025565878 %
#
# Percentage of correctly identified michel electrons:  96.30257528053605 %
# Percentage of reco michel electrons that are actually NULL:  0.7104222168402358 %
# Percentage of reco michel electrons that are actually SHOWER:  0.9687575684185032 %
# Percentage of reco michel electrons that are actually TRACK:  1.097925244207637 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  0.2018244934205215 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.7184951965770566 %
#
# Percentage of correctly identified delta electrons:  81.00470957613814 %
# Percentage of reco delta electrons that are actually NULL:  2.3824914581217103 %
# Percentage of reco delta electrons that are actually SHOWER:  0.5910056330224398 %
# Percentage of reco delta electrons that are actually TRACK:  14.350355526826114 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  1.0388770892972572 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  0.63256071659433 %

# %% [markdown]
# <h2 style="font-size: 24px;">4.2 NuMI Reco mode Particle semantic Type analysis energy cut</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/NuMI_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type", "reco_particle_ke"],library="pd")
combinedSEMANTIC

#Removing particles with true ke less than 10 MeV from the combinedSEMANTIC dataframe to focus on shower, track, michel electron and delta electron semantic types
combinedSEMANTIC = combinedSEMANTIC[combinedSEMANTIC["reco_particle_ke"] >= 10] 

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)]
correctrecoSHOWER
totalrecoSHOWER = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 0]
totalrecoSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totalrecoSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totalrecoSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totalrecoSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totalrecoSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totalrecoSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totalrecoSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)]
correctrecoTRACK
totalrecoTRACK = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 1]
totalrecoTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totalrecoTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totalrecoTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totalrecoTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totalrecoTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totalrecoTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totalrecoTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)]
correctrecoMICHEL
totalrecoMICHEL = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 2]
totalrecoMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totalrecoMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totalrecoMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totalrecoMICHEL))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totalrecoMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totalrecoMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totalrecoMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)]
correctrecoDELTA
totalrecoDELTA = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 3]
totalrecoDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totalrecoDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totalrecoDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totalrecoDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totalrecoDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totalrecoDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totalrecoDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")


#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron', 'Low Energy','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta,percentagewrongrecoSHOWERlowe, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percentagewrongrecoTRACKlowe, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percentagewrongrecoMICHELlowe, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percentagewrongrecoDELTAlowe, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('True Particle Semantic Type', fontsize=12)
plt.ylabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.title('NuMI Semantic Type Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  77.51561234354995 %
# Percentage of reco showers that are actually NULL:  9.129628177993782 %
# Percentage of reco showers that are actually TRACK:  2.4195866321757986 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  4.392359750202504 %
# Percentage of reco showers that are actually DELTA ELECTRON:  0.8753364166078754 %
# Percentage of reco showers that are actually LOW ENERGY:  5.667476679470094 %
#
# Percentage of correctly identified tracks:  97.07775913737974 %
# Percentage of reco tracks that are actually NULL:  1.1972871051461837 %
# Percentage of reco tracks that are actually SHOWER:  0.8617599403507262 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.6287549647983252 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.08674954474412469 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.14768930758090648 %
#
# Percentage of correctly identified michel electrons:  98.49707056126348 %
# Percentage of reco michel electrons that are actually NULL:  0.118875774815318 %
# Percentage of reco michel electrons that are actually SHOWER:  0.7472191559819988 %
# Percentage of reco michel electrons that are actually TRACK:  0.25473380317568145 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  0.059437887407659 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.3226628173558631 %
#
# Percentage of correctly identified delta electrons:  92.18926873443513 %
# Percentage of reco delta electrons that are actually NULL:  0.4754358161648178 %
# Percentage of reco delta electrons that are actually SHOWER:  1.6074258546524791 %
# Percentage of reco delta electrons that are actually TRACK:  1.3357482454154403 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  2.8073352954494 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  1.5847860538827259 %

# %% [markdown]
# <h2 style="font-size: 24px;">4.3 NuMI True mode Particle semantic Type analysis</h2>

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/NuMI_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type"],library="pd")
combinedSEMANTIC

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)]
correctrecoSHOWER
totaltrueSHOWER = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 0]
totaltrueSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totaltrueSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totaltrueSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totaltrueSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totaltrueSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totaltrueSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totaltrueSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)]
correctrecoTRACK
totaltrueTRACK = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 1]
totaltrueTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totaltrueTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totaltrueTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totaltrueTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totaltrueTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totaltrueTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totaltrueTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)]
correctrecoMICHEL
totaltrueMICHEL = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 2]
totaltrueMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totaltrueMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totaltrueMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totaltrueMICHEL   ))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totaltrueMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totaltrueMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totaltrueMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)]
correctrecoDELTA
totaltrueDELTA = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 3]
totaltrueDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totaltrueDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totaltrueDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totaltrueDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totaltrueDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totaltrueDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totaltrueDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")

#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.ylabel('True Particle Semantic Type', fontsize=12)
plt.title('NuMI Semantic Type Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  91.26517273576097 %
# Percentage of reco showers that are actually NULL:  6.34453781512605 %
# Percentage of reco showers that are actually TRACK:  1.0760971055088702 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  0.7282913165266106 %
# Percentage of reco showers that are actually DELTA ELECTRON:  0.5859010270774977 %
# Percentage of reco showers that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified tracks:  97.31456444515138 %
# Percentage of reco tracks that are actually NULL:  1.1332909177668204 %
# Percentage of reco tracks that are actually SHOWER:  1.4023646678330948 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.09941148401463337 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.050368485234080905 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified michel electrons:  82.66164747564217 %
# Percentage of reco michel electrons that are actually NULL:  0.40596397992323596 %
# Percentage of reco michel electrons that are actually SHOWER:  12.311780336581045 %
# Percentage of reco michel electrons that are actually TRACK:  3.616770002952465 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  1.0038382049010923 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified delta electrons:  81.85107024419656 %
# Percentage of reco delta electrons that are actually NULL:  0.7034468897598232 %
# Percentage of reco delta electrons that are actually SHOWER:  1.6430509496533012 %
# Percentage of reco delta electrons that are actually TRACK:  15.757210330620039 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  0.04522158577027434 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  0.0 %

# %% [markdown]
# <h2 style="font-size: 24px;">4.4 NuMI True mode Particle semantic Type analysis energy cut</h2>

# %%
#NuMI_CV_flat_cafs_2_00
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/NuMI_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type","true_particle_ke"],library="pd")
combinedSEMANTIC

#Removing particles with true ke less than 10 MeV from the combinedSEMANTIC dataframe to focus on shower, track, michel electron and delta electron semantic types
combinedSEMANTIC = combinedSEMANTIC[combinedSEMANTIC["true_particle_ke"] >= 10]    

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)]
correctrecoSHOWER
totaltrueSHOWER = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 0]
totaltrueSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totaltrueSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totaltrueSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totaltrueSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totaltrueSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totaltrueSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totaltrueSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)]
correctrecoTRACK
totaltrueTRACK = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 1]
totaltrueTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totaltrueTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totaltrueTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totaltrueTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totaltrueTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totaltrueTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totaltrueTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)]
correctrecoMICHEL
totaltrueMICHEL = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 2]
totaltrueMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totaltrueMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totaltrueMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totaltrueMICHEL   ))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totaltrueMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totaltrueMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totaltrueMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)]
correctrecoDELTA
totaltrueDELTA = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 3]
totaltrueDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totaltrueDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totaltrueDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totaltrueDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totaltrueDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totaltrueDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totaltrueDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")

#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.ylabel('True Particle Semantic Type', fontsize=12)
plt.title('NuMI Semantic Type Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  98.50703824825821 %
# Percentage of reco showers that are actually NULL:  0.20617090857386605 %
# Percentage of reco showers that are actually TRACK:  0.7002701549836485 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  0.34124840039812315 %
# Percentage of reco showers that are actually DELTA ELECTRON:  0.245272287786151 %
# Percentage of reco showers that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified tracks:  97.57779058281199 %
# Percentage of reco tracks that are actually NULL:  1.0200581714411152 %
# Percentage of reco tracks that are actually SHOWER:  1.305427505213478 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.047332894303589064 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.04939084622983208 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified michel electrons:  83.37726896136175 %
# Percentage of reco michel electrons that are actually NULL:  0.1882955486932289 %
# Percentage of reco michel electrons that are actually SHOWER:  12.48776078933494 %
# Percentage of reco michel electrons that are actually TRACK:  2.952474203509829 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  0.9942004971002486 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified delta electrons:  92.90563946238049 %
# Percentage of reco delta electrons that are actually NULL:  0.12470555632534293 %
# Percentage of reco delta electrons that are actually SHOWER:  3.0899265622834973 %
# Percentage of reco delta electrons that are actually TRACK:  3.824303727310517 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  0.05542469170015242 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  0.0 %

# %% [markdown]
# <h2 style="font-size: 24px;">4.5 BNB Reco mode Particle semantic Type analysis</h2>

# %%
#BNB 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/BNB_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type"],library="pd")
combinedSEMANTIC

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)]
correctrecoSHOWER
totalrecoSHOWER = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 0]
totalrecoSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totalrecoSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totalrecoSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totalrecoSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totalrecoSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totalrecoSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totalrecoSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)]
correctrecoTRACK
totalrecoTRACK = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 1]
totalrecoTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totalrecoTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totalrecoTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totalrecoTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totalrecoTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totalrecoTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totalrecoTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)]
correctrecoMICHEL
totalrecoMICHEL = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 2]
totalrecoMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totalrecoMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totalrecoMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totalrecoMICHEL))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totalrecoMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totalrecoMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totalrecoMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)]
correctrecoDELTA
totalrecoDELTA = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 3]
totalrecoDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totalrecoDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totalrecoDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totalrecoDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totalrecoDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totalrecoDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totalrecoDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")


#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron', 'Low Energy','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta,percentagewrongrecoSHOWERlowe, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percentagewrongrecoTRACKlowe, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percentagewrongrecoMICHELlowe, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percentagewrongrecoDELTAlowe, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('True Particle Semantic Type', fontsize=12)
plt.ylabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.title('BNB Semantic Type Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  40.93239869406568 %
# Percentage of reco showers that are actually NULL:  19.65719224121375 %
# Percentage of reco showers that are actually TRACK:  2.691569041674669 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  2.845208373343576 %
# Percentage of reco showers that are actually DELTA ELECTRON:  1.5075859420011524 %
# Percentage of reco showers that are actually LOW ENERGY:  32.36604570770117 %
#
# Percentage of correctly identified tracks:  97.67062952953292 %
# Percentage of reco tracks that are actually NULL:  1.0481683644609041 %
# Percentage of reco tracks that are actually SHOWER:  0.47138568051170726 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.6227125707682861 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.07445476389620813 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.11264909082997723 %
#
# Percentage of correctly identified michel electrons:  95.85452303898906 %
# Percentage of reco michel electrons that are actually NULL:  0.8629989212513484 %
# Percentage of reco michel electrons that are actually SHOWER:  1.0222427698155854 %
# Percentage of reco michel electrons that are actually TRACK:  1.191760415061386 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  0.24657112035752815 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.8219037345250937 %
#
# Percentage of correctly identified delta electrons:  81.33275450401563 %
# Percentage of reco delta electrons that are actually NULL:  2.219448665074886 %
# Percentage of reco delta electrons that are actually SHOWER:  0.42598220099848055 %
# Percentage of reco delta electrons that are actually TRACK:  14.678749728673758 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  0.7624267419144779 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  0.5806381593227697 %

# %% [markdown]
# <h2 style="font-size: 24px;">4.6 BNB Reco mode Particle semantic Type analysis energy cut</h2>

# %%
#BNB 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/BNB_simulation/particle_fiducial_flashmatch_containment_cut_reco"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type","reco_particle_ke"],library="pd")
combinedSEMANTIC

#Removing particles with true ke less than 10 MeV from the combinedSEMANTIC dataframe to focus on shower, track, michel electron and delta electron semantic types
combinedSEMANTIC = combinedSEMANTIC[combinedSEMANTIC["reco_particle_ke"] >= 10] 

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)]
correctrecoSHOWER
totalrecoSHOWER = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 0]
totalrecoSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totalrecoSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totalrecoSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totalrecoSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totalrecoSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totalrecoSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 0) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totalrecoSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)]
correctrecoTRACK
totalrecoTRACK = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 1]
totalrecoTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totalrecoTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totalrecoTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totalrecoTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totalrecoTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totalrecoTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 1) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totalrecoTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)]
correctrecoMICHEL
totalrecoMICHEL = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 2]
totalrecoMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totalrecoMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totalrecoMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totalrecoMICHEL))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totalrecoMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totalrecoMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 2) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totalrecoMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 3)]
correctrecoDELTA
totalrecoDELTA = combinedSEMANTIC[combinedSEMANTIC["reco_particle_semantic_type"] == 3]
totalrecoDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totalrecoDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totalrecoDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totalrecoDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totalrecoDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totalrecoDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["reco_particle_semantic_type"] == 3) & (combinedSEMANTIC["true_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totalrecoDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")


#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron', 'Low Energy','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta,percentagewrongrecoSHOWERlowe, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percentagewrongrecoTRACKlowe, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percentagewrongrecoMICHELlowe, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percentagewrongrecoDELTAlowe, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('True Particle Semantic Type', fontsize=12)
plt.ylabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.title('BNB Semantic Type Confusion Matrix: Reconstructed vs Truth (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  79.25577878591488 %
# Percentage of reco showers that are actually NULL:  5.230611363145387 %
# Percentage of reco showers that are actually TRACK:  2.662562108446749 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  5.468243681140636 %
# Percentage of reco showers that are actually DELTA ELECTRON:  1.0261395549794772 %
# Percentage of reco showers that are actually LOW ENERGY:  6.356664506372867 %
#
# Percentage of correctly identified tracks:  98.06867578842956 %
# Percentage of reco tracks that are actually NULL:  0.7949937275724246 %
# Percentage of reco tracks that are actually SHOWER:  0.42302418531376723 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.5460415633417939 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.06710038801528723 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.10016434732716788 %
#
# Percentage of correctly identified michel electrons:  98.43073593073593 %
# Percentage of reco michel electrons that are actually NULL:  0.15692640692640691 %
# Percentage of reco michel electrons that are actually SHOWER:  0.7521645021645021 %
# Percentage of reco michel electrons that are actually TRACK:  0.2326839826839827 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  0.091991341991342 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.3354978354978355 %
#
# Percentage of correctly identified delta electrons:  93.06278713629402 %
# Percentage of reco delta electrons that are actually NULL:  0.5513016845329249 %
# Percentage of reco delta electrons that are actually SHOWER:  1.316998468606432 %
# Percentage of reco delta electrons that are actually TRACK:  1.4854517611026032 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  2.23583460949464 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  1.3476263399693722 %

# %% [markdown]
# <h2 style="font-size: 24px;">4.7 BNB True mode Particle semantic Type analysis</h2>

# %%
#BNB 
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/BNB_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type"],library="pd")
combinedSEMANTIC

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)]
correctrecoSHOWER
totaltrueSHOWER = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 0]
totaltrueSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totaltrueSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totaltrueSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totaltrueSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totaltrueSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totaltrueSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totaltrueSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)]
correctrecoTRACK
totaltrueTRACK = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 1]
totaltrueTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totaltrueTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totaltrueTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totaltrueTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totaltrueTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totaltrueTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totaltrueTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)]
correctrecoMICHEL
totaltrueMICHEL = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 2]
totaltrueMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totaltrueMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totaltrueMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totaltrueMICHEL   ))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totaltrueMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totaltrueMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totaltrueMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)]
correctrecoDELTA
totaltrueDELTA = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 3]
totaltrueDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totaltrueDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totaltrueDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totaltrueDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totaltrueDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totaltrueDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totaltrueDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")

#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.ylabel('True Particle Semantic Type', fontsize=12)
plt.title('BNB Semantic Type Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  89.57410836486595 %
# Percentage of reco showers that are actually NULL:  7.614121246276468 %
# Percentage of reco showers that are actually TRACK:  1.07277996940665 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  0.9479913050479026 %
# Percentage of reco showers that are actually DELTA ELECTRON:  0.7909991144030272 %
# Percentage of reco showers that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified tracks:  97.70995619343071 %
# Percentage of reco tracks that are actually NULL:  1.2080897267629163 %
# Percentage of reco tracks that are actually SHOWER:  0.9204493156288884 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.10184601223856683 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.05965875193890943 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified michel electrons:  85.25352047218479 %
# Percentage of reco michel electrons that are actually NULL:  0.5484035878607613 %
# Percentage of reco michel electrons that are actually SHOWER:  10.001394246409816 %
# Percentage of reco michel electrons that are actually TRACK:  3.378723799786216 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  0.8179578937584235 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified delta electrons:  83.01285698031631 %
# Percentage of reco delta electrons that are actually NULL:  0.5063147115712823 %
# Percentage of reco delta electrons that are actually SHOWER:  1.0979633632950279 %
# Percentage of reco delta electrons that are actually TRACK:  15.306064398680169 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  0.07680054613721697 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  0.0 %

# %% [markdown]
# <h2 style="font-size: 24px;">4.8 BNB True mode Particle semantic Type analysis energy cut</h2>

# %%
#BNB 
#Preselection confusion matrix truth to reco selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_2_shower_event_preselection_PID_confusion_matrix_threshold.root:events/BNB_simulation/particle_fiducial_recoflashmatch_containment_cut_true"
)

#showing all TBranches
file.keys()

#Extracting and grouping reco and true semantic type variables from TBranches
combinedSEMANTIC = file.arrays(["reco_particle_semantic_type", "true_particle_semantic_type","true_particle_ke"],library="pd")
combinedSEMANTIC

#Removing particles with true ke less than 10 MeV from the combinedSEMANTIC dataframe to focus on shower, track, michel electron and delta electron semantic types
combinedSEMANTIC = combinedSEMANTIC[combinedSEMANTIC["true_particle_ke"] >= 10]    

# 0 = shower, 1 = track, 2 = Michel electron, 3 = delta electron, 4 = low-energy

#Shower semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified showers and total number of reco showers to calculate percentage of correctly identified showers
correctrecoSHOWER = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)]
correctrecoSHOWER
totaltrueSHOWER = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 0]
totaltrueSHOWER

#calculating percentage of correctly identified showers
percentagecorrectSHOWER = (len(correctrecoSHOWER)/len(totaltrueSHOWER))*100
percentagecorrectSHOWER

#calculating percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoSHOWERNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoSHOWERNULL = (len(wrongrecoSHOWERNull)/len(totaltrueSHOWER))*100
wrongrecoSHOWERtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoSHOWERtrack = (len(wrongrecoSHOWERtrack)/len(totaltrueSHOWER   ))*100
wrongrecoSHOWERmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoSHOWERmichel = (len(wrongrecoSHOWERmichel)/len(totaltrueSHOWER))*100
wrongrecoSHOWERdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoSHOWERdelta = (len(wrongrecoSHOWERdelta)/len(totaltrueSHOWER))*100
wrongrecoSHOWERlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 0) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoSHOWERlowe = (len(wrongrecoSHOWERlowe)/len(totaltrueSHOWER))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("Percentage of correctly identified showers: ", percentagecorrectSHOWER, "%")
print("Percentage of reco showers that are actually NULL: ", percenragewrongrecoSHOWERNULL, "%")
print("Percentage of reco showers that are actually TRACK: ", percentagewrongrecoSHOWERtrack, "%")
print("Percentage of reco showers that are actually MICHEL ELECTRON: ", percentagewrongrecoSHOWERmichel, "%")
print("Percentage of reco showers that are actually DELTA ELECTRON: ", percentagewrongrecoSHOWERdelta, "%")
print("Percentage of reco showers that are actually LOW ENERGY: ", percentagewrongrecoSHOWERlowe, "%")

#Track semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified tracks and total number of true tracks to calculate percentage of correctly identified tracks
correctrecoTRACK = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)]
correctrecoTRACK
totaltrueTRACK = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 1]
totaltrueTRACK

#calculating percentage of correctly identified tracks
percentagecorrectTRACK = (len(correctrecoTRACK)/len(totaltrueTRACK))*100
percentagecorrectTRACK

#calculating percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoTRACKNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoTRACKNull = (len(wrongrecoTRACKNull)/len(totaltrueTRACK))*100
wrongrecoTRACKshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoTRACKshower = (len(wrongrecoTRACKshower)/len(totaltrueTRACK   ))*100
wrongrecoTRACKmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoTRACKmichel = (len(wrongrecoTRACKmichel)/len(totaltrueTRACK))*100
wrongrecoTRACKdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoTRACKdelta = (len(wrongrecoTRACKdelta)/len(totaltrueTRACK))*100
wrongrecoTRACKlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 1) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoTRACKlowe = (len(wrongrecoTRACKlowe)/len(totaltrueTRACK))*100

#printing percentage of correctly identified tracks and percentage of reco tracks that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified tracks: ", percentagecorrectTRACK, "%")
print("Percentage of reco tracks that are actually NULL: ", percenragewrongrecoTRACKNull, "%")
print("Percentage of reco tracks that are actually SHOWER: ", percentagewrongrecoTRACKshower, "%")
print("Percentage of reco tracks that are actually MICHEL ELECTRON: ", percentagewrongrecoTRACKmichel, "%")
print("Percentage of reco tracks that are actually DELTA ELECTRON: ", percentagewrongrecoTRACKdelta, "%")
print("Percentage of reco tracks that are actually LOW ENERGY: ", percentagewrongrecoTRACKlowe, "%")

#Michel electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified michel and total number of true michel to calculate percentage of correctly identified michel
correctrecoMICHEL = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)]
correctrecoMICHEL
totaltrueMICHEL = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 2]
totaltrueMICHEL

#calculating percentage of correctly identified michel
percentagecorrectMICHEL = (len(correctrecoMICHEL)/len(totaltrueMICHEL))*100
percentagecorrectMICHEL

#calculating percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoMICHELNull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoMICHELNull = (len(wrongrecoMICHELNull)/len(totaltrueMICHEL))*100
wrongrecoMICHELshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoMICHELshower = (len(wrongrecoMICHELshower)/len(totaltrueMICHEL   ))*100
wrongrecoMICHELtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoMICHELtrack = (len(wrongrecoMICHELtrack)/len(totaltrueMICHEL))*100
wrongrecoMICHELdelta = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)] 
percentagewrongrecoMICHELdelta = (len(wrongrecoMICHELdelta)/len(totaltrueMICHEL))*100
wrongrecoMICHELlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 2) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoMICHELlowe = (len(wrongrecoMICHELlowe)/len(totaltrueMICHEL))*100

#printing percentage of correctly identified michel and percentage of reco michel that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified michel electrons: ", percentagecorrectMICHEL, "%")
print("Percentage of reco michel electrons that are actually NULL: ", percenragewrongrecoMICHELNull, "%")
print("Percentage of reco michel electrons that are actually SHOWER: ", percentagewrongrecoMICHELshower, "%")
print("Percentage of reco michel electrons that are actually TRACK: ", percentagewrongrecoMICHELtrack, "%")
print("Percentage of reco michel electrons that are actually DELTA ELECTRON: ", percentagewrongrecoMICHELdelta, "%")
print("Percentage of reco michel electrons that are actually LOW ENERGY: ", percentagewrongrecoMICHELlowe, "%")

#Delta electron semantic ---------------------------------------------------------------------------------------------------------------------------------

#finding number of correctly identified delta and total number of true delta to calculate percentage of correctly identified delta
correctrecoDELTA = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 3)]
correctrecoDELTA
totaltrueDELTA = combinedSEMANTIC[combinedSEMANTIC["true_particle_semantic_type"] == 3]
totaltrueDELTA

#calculating percentage of correctly identified delta
percentagecorrectDELTA = (len(correctrecoDELTA)/len(totaltrueDELTA))*100
percentagecorrectDELTA

#calculating percentage of reco delta that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
wrongrecoDELTANull = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"].isna())]
percenragewrongrecoDELTANull = (len(wrongrecoDELTANull)/len(totaltrueDELTA))*100
wrongrecoDELTAshower = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 0)] 
percentagewrongrecoDELTAshower = (len(wrongrecoDELTAshower)/len(totaltrueDELTA   ))*100
wrongrecoDELTAtrack = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 1)] 
percentagewrongrecoDELTAtrack = (len(wrongrecoDELTAtrack)/len(totaltrueDELTA))*100
wrongrecoDELTAmichel = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 2)] 
percentagewrongrecoDELTAmichel = (len(wrongrecoDELTAmichel)/len(totaltrueDELTA))*100
wrongrecoDELTAlowe = combinedSEMANTIC[(combinedSEMANTIC["true_particle_semantic_type"] == 3) & (combinedSEMANTIC["reco_particle_semantic_type"] == 4)] 
percentagewrongrecoDELTAlowe = (len(wrongrecoDELTAlowe)/len(totaltrueDELTA))*100

#printing percentage of correctly identified showers and percentage of reco showers that are actually NULL, TRACK, ELECTRON, PROTON, MICHEL, GHOST
print("\nPercentage of correctly identified delta electrons: ", percentagecorrectDELTA, "%")
print("Percentage of reco delta electrons that are actually NULL: ", percenragewrongrecoDELTANull, "%")
print("Percentage of reco delta electrons that are actually SHOWER: ", percentagewrongrecoDELTAshower, "%")
print("Percentage of reco delta electrons that are actually TRACK: ", percentagewrongrecoDELTAtrack, "%")
print("Percentage of reco delta electrons that are actually MICHEL ELECTRON: ", percentagewrongrecoDELTAmichel, "%")
print("Percentage of reco delta electrons that are actually LOW ENERGY: ", percentagewrongrecoDELTAlowe, "%")

#creating confusion matrix for reco to true semantic type selection
# Data from your analysis
yparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron']
xparticle_names = ['Shower', 'Track', 'Michel Electron', 'Delta Electron','NULL']

# Create confusion matrix (rows = reco, columns = true)
# Including NULL column
confusion_matrix = np.array([
    [percentagecorrectSHOWER, percentagewrongrecoSHOWERtrack, percentagewrongrecoSHOWERmichel, percentagewrongrecoSHOWERdelta, percenragewrongrecoSHOWERNULL],
    [percentagewrongrecoTRACKshower, percentagecorrectTRACK, percentagewrongrecoTRACKmichel, percentagewrongrecoTRACKdelta, percenragewrongrecoTRACKNull],
    [percentagewrongrecoMICHELshower, percentagewrongrecoMICHELtrack, percentagecorrectMICHEL, percentagewrongrecoMICHELdelta, percenragewrongrecoMICHELNull],
    [percentagewrongrecoDELTAshower, percentagewrongrecoDELTAtrack, percentagewrongrecoDELTAmichel, percentagecorrectDELTA, percenragewrongrecoDELTANull]
])

# Create heatmap with custom formatting
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=xparticle_names, yticklabels=yparticle_names,
            cbar_kws={'label': 'Percentage (%)'},
            annot_kws={'fontsize': 10})
# Add % signs manually to annotations
ax = plt.gca()
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xlabel('Reconstructed Particle Semantic Type', fontsize=12)
plt.ylabel('True Particle Semantic Type', fontsize=12)
plt.title('BNB Semantic Type Confusion Matrix: Truth vs Reconstructed (Including NULL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Percentage of correctly identified showers:  98.47380023740885 %
# Percentage of reco showers that are actually NULL:  0.25097507207054437 %
# Percentage of reco showers that are actually TRACK:  0.5799559097846362 %
# Percentage of reco showers that are actually MICHEL ELECTRON:  0.4612514838053247 %
# Percentage of reco showers that are actually DELTA ELECTRON:  0.2340172969306427 %
# Percentage of reco showers that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified tracks:  97.98390821789452 %
# Percentage of reco tracks that are actually NULL:  1.0579752860492433 %
# Percentage of reco tracks that are actually SHOWER:  0.8644163979570738 %
# Percentage of reco tracks that are actually MICHEL ELECTRON:  0.03651224479920465 %
# Percentage of reco tracks that are actually DELTA ELECTRON:  0.05718785329995909 %
# Percentage of reco tracks that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified michel electrons:  86.27226826712395 %
# Percentage of reco michel electrons that are actually NULL:  0.23816328474802326 %
# Percentage of reco michel electrons that are actually SHOWER:  10.188625321520435 %
# Percentage of reco michel electrons that are actually TRACK:  2.4864246927693627 %
# Percentage of reco michel electrons that are actually DELTA ELECTRON:  0.8145184338382395 %
# Percentage of reco michel electrons that are actually LOW ENERGY:  0.0 %
#
# Percentage of correctly identified delta electrons:  93.5704053256931 %
# Percentage of reco delta electrons that are actually NULL:  0.10112075503497092 %
# Percentage of reco delta electrons that are actually SHOWER:  2.460605039184293 %
# Percentage of reco delta electrons that are actually TRACK:  3.7161877475351814 %
# Percentage of reco delta electrons that are actually MICHEL ELECTRON:  0.1516811325524564 %
# Percentage of reco delta electrons that are actually LOW ENERGY:  0.0 %

# %%
#NuMI_CV_flat_cafs_2_00 
#Preselection confusion matrix reco to truth selection 

#Importing relevant libraries
import numpy as np
import uproot
import pandas
import hist
import matplotlib.pyplot as plt
import seaborn as sns


#enable this to see all outputs in a cell
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

#Opening the relevant ROOT file and tree
file = uproot.open(
    "e:/FYP/medulla_outputs/All_NuMI_BNB_event_level_info_2.root:events/NuMI_simulation/events_NuMI"
)

file.keys()

nnu = file.arrays(["event_nnu"],library="pd")

#group identical rows and count together
nnu_counts = nnu.groupby("event_nnu").size().reset_index(name="count")
nnu_counts
# Out:
#    event_nnu   count
# 0        0.0   92844
# 1        1.0  175880
# 2        2.0   14855
# 3        3.0     654
# 4        4.0      25
# 5        5.0       2
